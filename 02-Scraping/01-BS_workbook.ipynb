# %% [markdown]
# # Webscraping with Beautiful Soup
# *****
# In this lesson we'll learn about various techniques to scrape data from websites. This lesson will include:
#
# 0. Discussion of complying with Terms of Use
# 1. Using Python's `BeautifulSoup` library
# 2. Collecting data from one page
# 3. Following collected links
# 4. Exporting data to CSV
#
#
# # 0. Terms of Use
# We'll be scraping [information on the state senators of Illinois](http://www.ilga.gov/senate), as well as the [list of bills](http://www.ilga.gov/senate/SenatorBills.asp?MemberID=1911&GA=98&Primary=True) from the Illinois General Assembly. Your first step before scraping should always be to read the Terms of Use or Terms of Agreement for a website. Many websites will explicitly prohibit scraping in any form. Moreover, if you're affiliated with an institution, you may be breaching existing contracts by engaging in scraping. UC Berkeley's Library [recommends](http://guides.lib.berkeley.edu/text-mining) following this workflow:
#
# ![UCB-library-workflow](img/UCB-library-workflow.png)
#
# While our source's [Terms of Use](http://www.ilga.gov/disclaimer.asp) do not explicitly prohibit scraping (nor do their [robots.txt](http://www.ilga.gov/robots.txt)), it is advisable to still contact the web administrator of the website. We will not be placing too much stress on their servers today, so please keep this in mind while following along and executing the code. You should always attempt to contact the web administrator of the site you plan to scrape. Oftentimes there is an easier way to get the data that you want.
#
# Let's go ahead and import the Python libraries we'll need:

# %%
import requests  # to make GET request
from bs4 import BeautifulSoup  # to parse the HTML response
import time  # to pause between calls
import csv  # to write data to csv
import pandas  # to see CSV

# %% [markdown]
# # 1. Using `BeautifulSoup`
# *****
#
# ## 1.1 Make a GET request and parse the HTML response
#
# We use the `requests` library just as we did with APIs, but this time we won't get JSON or XML back, but we'll get an HTML response.

# %%
# make a GET request
response = requests.get('http://www.ilga.gov/senate/default.asp')

# read the content of the server’s response as a string
page_source = response.text
print(page_source[:1000])
# Out:
# <html lang="en">
#
# <title>Illinois General Assembly - Senate Members</title>
#
# <head>
#
# <link rel="stylesheet" type="text/css" href="/style/lis.css">
# <link rel="stylesheet" type="text/css" media="print" href="/style/print.css">
# <link rel="GILS" href="http://info.er.usgs.gov/public/gils/gilsexec.html">
# <link rel="Shortcut Icon" HREF="/LISlogo1.ico">
# <SCRIPT LANGUAGE="JavaScript" TYPE="text/javascript">
# <!--
#
# if(window.event + "" == "undefined") event = null;
# function HM_f_PopUp(){return false};
# function HM_f_PopDown(){return false};
# popUp = HM_f_PopUp;
# popDown = HM_f_PopDown;
#
# //-->
# </SCRIPT>
#
# <!--
#     option explicit
#   -->
# <meta http-equiv="PICS-Label" content='(PICS-1.1 "http://www.weburbia.com/safe/ratings.htm" l r (s 0))'>
# <meta name="classification" content="Government">
# <meta name="distribution" content="Global">
# <meta name="rating" content="General">
# <meta name="contactState" content="IL">
# <meta name="siteTitle" content="Illinois General Assembly">
# <meta name=

# %% [markdown]
# ## 1.2 *soup* it
#
# Now we use the `BeautifulSoup` function to make an object of the response, which allows us to parse the HTML tree. This returns an object (called a *soup* object) with all of the HTML in the original document.

# %%
# parse the response into an HTML tree soup object
soup = BeautifulSoup(page_source, 'html5lib')

# take a look
print(soup.prettify()[:1000])
# Out:
# <html lang="en">
#  <head>
#   <title>
#    Illinois General Assembly - Senate Members
#   </title>
#   <link href="/style/lis.css" rel="stylesheet" type="text/css"/>
#   <link href="/style/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="http://info.er.usgs.gov/public/gils/gilsexec.html" rel="GILS"/>
#   <link href="/LISlogo1.ico" rel="Shortcut Icon"/>
#   <script language="JavaScript" type="text/javascript">
#    <!--
#
# if(window.event + "" == "undefined") event = null;
# function HM_f_PopUp(){return false};
# function HM_f_PopDown(){return false};
# popUp = HM_f_PopUp;
# popDown = HM_f_PopDown;
#
# //-->
#   </script>
#   <!--
#     option explicit
#   -->
#   <meta content='(PICS-1.1 "http://www.weburbia.com/safe/ratings.htm" l r (s 0))' http-equiv="PICS-Label"/>
#   <meta content="Government" name="classification"/>
#   <meta content="Global" name="distribution"/>
#   <meta content="General" name="rating"/>
#   <meta content="IL" name="contactState"/>
#   <meta content="Illinois General Assembly" name="si

# %% [markdown]
# ## 1.3 Find Elements
#
# `BeautifulSoup` has a number of functions to find things on a page. Like other scraping tools, `BeautifulSoup` lets you find elements by their:
#
# 1. HTML tags
# 2. HTML Attributes
# 3. CSS Selectors
#
#
# Let's search first for **HTML tags**.
#
# The function `find_all` searches the `soup` tree to find all the elements with a particular HTML tag, and returns all of those elements.
#
# What does the example below do?

# %%
soup.find_all("a")
# Out:
# [<a href="/default.asp"><img alt="Illinois General Assembly" border="0" height="49" src="/images/logo_sm.gif" width="462"/></a>,
#  <a class="mainmenu" href="/">Home</a>,
#  <a class="mainmenu" href="/legislation/" onblur="HM_f_PopDown('elMenu1')" onfocus="HM_f_PopUp('elMenu1',event)" onmouseout="HM_f_PopDown('elMenu1')" onmouseover="HM_f_PopUp('elMenu1',event)">Legislation &amp; Laws</a>,
#  <a class="mainmenu" href="/senate/" onblur="HM_f_PopDown('elMenu3')" onfocus="HM_f_PopUp('elMenu3',event)" onmouseout="HM_f_PopDown('elMenu3')" onmouseover="HM_f_PopUp('elMenu3',event)">Senate</a>,
#  <a class="mainmenu" href="/house/" onblur="HM_f_PopDown('elMenu2')" onfocus="HM_f_PopUp('elMenu2',event)" onmouseout="HM_f_PopDown('elMenu2')" onmouseover="HM_f_PopUp('elMenu2',event)">House</a>,
#  <a class="mainmenu" href="/mylegislation/" onblur="HM_f_PopDown('elMenu4')" onfocus="HM_f_PopUp('elMenu4',event)" onmouseout="HM_f_PopDown('elMenu4')" onmouseover="HM_f_PopUp('elMenu4',event)">My Legislation</a>,
#  <a class="mainmenu" href="/sitemap.asp">Site Map</a>,
#  <a class="sidemenu" href="/senate/default.asp">  Members  </a>,
#  <a class="sidemenu" href="/senate/committees/default.asp">  Committees  </a>,
#  <a class="sidemenu" href="/senate/schedules/default.asp">  Schedules  </a>,
#  <a class="sidemenu" href="/senate/journals/default.asp">  Journals  </a>,
#  <a class="sidemenu" href="/senate/transcripts/default.asp">  Transcripts  </a>,
#  <a class="sidemenu" href="/senate/rules.asp">  Rules  </a>,
#  <a class="sidemenu" href="/senateaudvid.asp">  Live Audio/Video  </a>,
#  <a href="100GA_Senate_Leadership.pdf">Leadership</a>,
#  <a href="100GA_Senate_Officers.pdf">Officers</a>,
#  <a href="100GA_Senate_Seating_Chart.pdf">Senate Seating Chart</a>,
#  <a class="filetab" href="javascript:Sort('LastName','',100);" title="Sort by Senator">Senator</a>,
#  <a class="filetab" href="javascript:Sort('DistrictNumber','',100);" title="Sort by District">District</a>,
#  <a class="filetab" href="javascript:Sort('Party','',100);" title="Sort by Party">Party</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2335">Pamela J. Althoff</a>,
#  <a href="SenatorBills.asp?MemberID=2335">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2335">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2464">Neil Anderson</a>,
#  <a href="SenatorBills.asp?MemberID=2464">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2464">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2474">Omar Aquino</a>,
#  <a href="SenatorBills.asp?MemberID=2474">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2474">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2403">Jason A. Barickman</a>,
#  <a href="SenatorBills.asp?MemberID=2403">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2403">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2465">Scott M. Bennett</a>,
#  <a href="SenatorBills.asp?MemberID=2465">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2465">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2405">Jennifer Bertino-Tarrant</a>,
#  <a href="SenatorBills.asp?MemberID=2405">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2405">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2404">Daniel Biss</a>,
#  <a href="SenatorBills.asp?MemberID=2404">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2404">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2361">Tim Bivins</a>,
#  <a href="SenatorBills.asp?MemberID=2361">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2361">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2318">William E. Brady</a>,
#  <a href="SenatorBills.asp?MemberID=2318">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2318">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2406">Melinda Bush</a>,
#  <a href="SenatorBills.asp?MemberID=2406">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2406">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2482">Cristina Castro</a>,
#  <a href="SenatorBills.asp?MemberID=2482">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2482">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2308">James F. Clayborne, Jr.</a>,
#  <a href="SenatorBills.asp?MemberID=2308">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2308">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2328">Jacqueline Y. Collins</a>,
#  <a href="SenatorBills.asp?MemberID=2328">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2328">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2407">Michael Connelly</a>,
#  <a href="SenatorBills.asp?MemberID=2407">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2407">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2309">John J. Cullerton</a>,
#  <a href="SenatorBills.asp?MemberID=2309">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2309">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2408">Thomas Cullerton</a>,
#  <a href="SenatorBills.asp?MemberID=2408">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2408">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2409">Bill Cunningham</a>,
#  <a href="SenatorBills.asp?MemberID=2409">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2409">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2483">Dale Fowler</a>,
#  <a href="SenatorBills.asp?MemberID=2483">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2483">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2333">William R. Haine</a>,
#  <a href="SenatorBills.asp?MemberID=2333">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2333">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2330">Don Harmon</a>,
#  <a href="SenatorBills.asp?MemberID=2330">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2330">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2410">Napoleon Harris, III</a>,
#  <a href="SenatorBills.asp?MemberID=2410">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2410">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2411">Michael E. Hastings</a>,
#  <a href="SenatorBills.asp?MemberID=2411">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2411">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2353">Linda Holmes</a>,
#  <a href="SenatorBills.asp?MemberID=2353">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2353">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2334">Mattie Hunter</a>,
#  <a href="SenatorBills.asp?MemberID=2334">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2334">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2368">Toi W. Hutchinson</a>,
#  <a href="SenatorBills.asp?MemberID=2368">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2368">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2370">Emil Jones, III</a>,
#  <a href="SenatorBills.asp?MemberID=2370">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2370">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2354">David Koehler</a>,
#  <a href="SenatorBills.asp?MemberID=2354">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2354">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2394">Steven M. Landek</a>,
#  <a href="SenatorBills.asp?MemberID=2394">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2394">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2310">Kimberly A. Lightford</a>,
#  <a href="SenatorBills.asp?MemberID=2310">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2310">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2311">Terry Link</a>,
#  <a href="SenatorBills.asp?MemberID=2311">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2311">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2412">Andy Manar</a>,
#  <a href="SenatorBills.asp?MemberID=2412">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2412">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2329">Iris Y. Martinez</a>,
#  <a href="SenatorBills.asp?MemberID=2329">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2329">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2393">Wm. Sam McCann</a>,
#  <a href="SenatorBills.asp?MemberID=2393">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2393">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2371">Kyle McCarter</a>,
#  <a href="SenatorBills.asp?MemberID=2371">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2371">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2473">Dan McConchie</a>,
#  <a href="SenatorBills.asp?MemberID=2473">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2473">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2413">Karen McConnaughay</a>,
#  <a href="SenatorBills.asp?MemberID=2413">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2413">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2398">Pat McGuire</a>,
#  <a href="SenatorBills.asp?MemberID=2398">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2398">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2414">Julie A. Morrison</a>,
#  <a href="SenatorBills.asp?MemberID=2414">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2414">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2377">John G. Mulroe</a>,
#  <a href="SenatorBills.asp?MemberID=2377">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2377">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2313">Antonio Muñoz</a>,
#  <a href="SenatorBills.asp?MemberID=2313">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2313">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2468">Laura M. Murphy</a>,
#  <a href="SenatorBills.asp?MemberID=2468">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2468">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2449">Chris Nybo</a>,
#  <a href="SenatorBills.asp?MemberID=2449">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2449">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2415">Jim Oberweis</a>,
#  <a href="SenatorBills.asp?MemberID=2415">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2415">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2314">Christine Radogno</a>,
#  <a href="SenatorBills.asp?MemberID=2314">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2314">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2340">Kwame Raoul</a>,
#  <a href="SenatorBills.asp?MemberID=2340">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2340">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2379">Sue Rezin</a>,
#  <a href="SenatorBills.asp?MemberID=2379">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2379">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2332">Dale A. Righter</a>,
#  <a href="SenatorBills.asp?MemberID=2332">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2332">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2477">Tom Rooney</a>,
#  <a href="SenatorBills.asp?MemberID=2477">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2477">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2416">Chapin Rose</a>,
#  <a href="SenatorBills.asp?MemberID=2416">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2416">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2327">Martin A. Sandoval</a>,
#  <a href="SenatorBills.asp?MemberID=2327">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2327">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2484">Paul Schimpf</a>,
#  <a href="SenatorBills.asp?MemberID=2484">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2484">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2315">Ira I. Silverstein</a>,
#  <a href="SenatorBills.asp?MemberID=2315">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2315">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2417">Steve Stadelman</a>,
#  <a href="SenatorBills.asp?MemberID=2417">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2417">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2360">Heather A. Steans</a>,
#  <a href="SenatorBills.asp?MemberID=2360">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2360">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2316">Dave Syverson</a>,
#  <a href="SenatorBills.asp?MemberID=2316">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2316">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2485">Jil Tracy</a>,
#  <a href="SenatorBills.asp?MemberID=2485">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2485">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2317">Donne E. Trotter</a>,
#  <a href="SenatorBills.asp?MemberID=2317">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2317">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2418">Patricia Van Pelt</a>,
#  <a href="SenatorBills.asp?MemberID=2418">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2418">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2469">Chuck Weaver</a>,
#  <a href="SenatorBills.asp?MemberID=2469">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2469">Committees</a>,
#  <a href="/reports/rptMemberList.asp?gaid=14&amp;ChamberId=S" target="new">click here</a>,
#  <a class="footer" href="/" title="View the General Assembly web site home page">Home</a>,
#  <a class="footer" href="/legislation/" title="View Legislation and Laws">Legislation &amp; Laws</a>,
#  <a class="footer" href="/house/default.asp" title="View information regarding House of Representatives">House</a>,
#  <a class="footer" href="/senate/default.asp" title="View information regarding Senate">Senate</a>,
#  <a class="footer" href="/mylegislation/default.asp" title="Set up customized queries, create reports for tracking, etc.">My Legislation</a>,
#  <a class="footer" href="/disclaimer.asp" title="Disclaimers regarding the Illinois General Assembly web site">Disclaimers</a>,
#  <a class="footer" href="/contact.asp" title="Contact the Illinois General Assembly Web Support Staff">Email</a>]

# %% [markdown]
# **NB**: Because `find_all()` is the most popular method in the `BeautifulSoup` search library, you can use a shortcut for it. If you treat the `BeautifulSoup` object as though it were a function, then it’s the same as calling `find_all()` on that object.

# %%
soup("a")
# Out:
# [<a href="/default.asp"><img alt="Illinois General Assembly" border="0" height="49" src="/images/logo_sm.gif" width="462"/></a>,
#  <a class="mainmenu" href="/">Home</a>,
#  <a class="mainmenu" href="/legislation/" onblur="HM_f_PopDown('elMenu1')" onfocus="HM_f_PopUp('elMenu1',event)" onmouseout="HM_f_PopDown('elMenu1')" onmouseover="HM_f_PopUp('elMenu1',event)">Legislation &amp; Laws</a>,
#  <a class="mainmenu" href="/senate/" onblur="HM_f_PopDown('elMenu3')" onfocus="HM_f_PopUp('elMenu3',event)" onmouseout="HM_f_PopDown('elMenu3')" onmouseover="HM_f_PopUp('elMenu3',event)">Senate</a>,
#  <a class="mainmenu" href="/house/" onblur="HM_f_PopDown('elMenu2')" onfocus="HM_f_PopUp('elMenu2',event)" onmouseout="HM_f_PopDown('elMenu2')" onmouseover="HM_f_PopUp('elMenu2',event)">House</a>,
#  <a class="mainmenu" href="/mylegislation/" onblur="HM_f_PopDown('elMenu4')" onfocus="HM_f_PopUp('elMenu4',event)" onmouseout="HM_f_PopDown('elMenu4')" onmouseover="HM_f_PopUp('elMenu4',event)">My Legislation</a>,
#  <a class="mainmenu" href="/sitemap.asp">Site Map</a>,
#  <a class="sidemenu" href="/senate/default.asp">  Members  </a>,
#  <a class="sidemenu" href="/senate/committees/default.asp">  Committees  </a>,
#  <a class="sidemenu" href="/senate/schedules/default.asp">  Schedules  </a>,
#  <a class="sidemenu" href="/senate/journals/default.asp">  Journals  </a>,
#  <a class="sidemenu" href="/senate/transcripts/default.asp">  Transcripts  </a>,
#  <a class="sidemenu" href="/senate/rules.asp">  Rules  </a>,
#  <a class="sidemenu" href="/senateaudvid.asp">  Live Audio/Video  </a>,
#  <a href="100GA_Senate_Leadership.pdf">Leadership</a>,
#  <a href="100GA_Senate_Officers.pdf">Officers</a>,
#  <a href="100GA_Senate_Seating_Chart.pdf">Senate Seating Chart</a>,
#  <a class="filetab" href="javascript:Sort('LastName','',100);" title="Sort by Senator">Senator</a>,
#  <a class="filetab" href="javascript:Sort('DistrictNumber','',100);" title="Sort by District">District</a>,
#  <a class="filetab" href="javascript:Sort('Party','',100);" title="Sort by Party">Party</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2335">Pamela J. Althoff</a>,
#  <a href="SenatorBills.asp?MemberID=2335">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2335">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2464">Neil Anderson</a>,
#  <a href="SenatorBills.asp?MemberID=2464">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2464">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2474">Omar Aquino</a>,
#  <a href="SenatorBills.asp?MemberID=2474">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2474">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2403">Jason A. Barickman</a>,
#  <a href="SenatorBills.asp?MemberID=2403">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2403">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2465">Scott M. Bennett</a>,
#  <a href="SenatorBills.asp?MemberID=2465">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2465">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2405">Jennifer Bertino-Tarrant</a>,
#  <a href="SenatorBills.asp?MemberID=2405">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2405">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2404">Daniel Biss</a>,
#  <a href="SenatorBills.asp?MemberID=2404">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2404">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2361">Tim Bivins</a>,
#  <a href="SenatorBills.asp?MemberID=2361">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2361">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2318">William E. Brady</a>,
#  <a href="SenatorBills.asp?MemberID=2318">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2318">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2406">Melinda Bush</a>,
#  <a href="SenatorBills.asp?MemberID=2406">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2406">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2482">Cristina Castro</a>,
#  <a href="SenatorBills.asp?MemberID=2482">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2482">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2308">James F. Clayborne, Jr.</a>,
#  <a href="SenatorBills.asp?MemberID=2308">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2308">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2328">Jacqueline Y. Collins</a>,
#  <a href="SenatorBills.asp?MemberID=2328">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2328">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2407">Michael Connelly</a>,
#  <a href="SenatorBills.asp?MemberID=2407">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2407">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2309">John J. Cullerton</a>,
#  <a href="SenatorBills.asp?MemberID=2309">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2309">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2408">Thomas Cullerton</a>,
#  <a href="SenatorBills.asp?MemberID=2408">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2408">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2409">Bill Cunningham</a>,
#  <a href="SenatorBills.asp?MemberID=2409">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2409">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2483">Dale Fowler</a>,
#  <a href="SenatorBills.asp?MemberID=2483">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2483">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2333">William R. Haine</a>,
#  <a href="SenatorBills.asp?MemberID=2333">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2333">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2330">Don Harmon</a>,
#  <a href="SenatorBills.asp?MemberID=2330">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2330">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2410">Napoleon Harris, III</a>,
#  <a href="SenatorBills.asp?MemberID=2410">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2410">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2411">Michael E. Hastings</a>,
#  <a href="SenatorBills.asp?MemberID=2411">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2411">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2353">Linda Holmes</a>,
#  <a href="SenatorBills.asp?MemberID=2353">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2353">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2334">Mattie Hunter</a>,
#  <a href="SenatorBills.asp?MemberID=2334">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2334">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2368">Toi W. Hutchinson</a>,
#  <a href="SenatorBills.asp?MemberID=2368">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2368">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2370">Emil Jones, III</a>,
#  <a href="SenatorBills.asp?MemberID=2370">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2370">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2354">David Koehler</a>,
#  <a href="SenatorBills.asp?MemberID=2354">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2354">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2394">Steven M. Landek</a>,
#  <a href="SenatorBills.asp?MemberID=2394">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2394">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2310">Kimberly A. Lightford</a>,
#  <a href="SenatorBills.asp?MemberID=2310">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2310">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2311">Terry Link</a>,
#  <a href="SenatorBills.asp?MemberID=2311">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2311">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2412">Andy Manar</a>,
#  <a href="SenatorBills.asp?MemberID=2412">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2412">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2329">Iris Y. Martinez</a>,
#  <a href="SenatorBills.asp?MemberID=2329">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2329">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2393">Wm. Sam McCann</a>,
#  <a href="SenatorBills.asp?MemberID=2393">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2393">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2371">Kyle McCarter</a>,
#  <a href="SenatorBills.asp?MemberID=2371">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2371">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2473">Dan McConchie</a>,
#  <a href="SenatorBills.asp?MemberID=2473">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2473">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2413">Karen McConnaughay</a>,
#  <a href="SenatorBills.asp?MemberID=2413">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2413">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2398">Pat McGuire</a>,
#  <a href="SenatorBills.asp?MemberID=2398">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2398">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2414">Julie A. Morrison</a>,
#  <a href="SenatorBills.asp?MemberID=2414">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2414">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2377">John G. Mulroe</a>,
#  <a href="SenatorBills.asp?MemberID=2377">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2377">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2313">Antonio Muñoz</a>,
#  <a href="SenatorBills.asp?MemberID=2313">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2313">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2468">Laura M. Murphy</a>,
#  <a href="SenatorBills.asp?MemberID=2468">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2468">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2449">Chris Nybo</a>,
#  <a href="SenatorBills.asp?MemberID=2449">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2449">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2415">Jim Oberweis</a>,
#  <a href="SenatorBills.asp?MemberID=2415">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2415">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2314">Christine Radogno</a>,
#  <a href="SenatorBills.asp?MemberID=2314">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2314">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2340">Kwame Raoul</a>,
#  <a href="SenatorBills.asp?MemberID=2340">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2340">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2379">Sue Rezin</a>,
#  <a href="SenatorBills.asp?MemberID=2379">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2379">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2332">Dale A. Righter</a>,
#  <a href="SenatorBills.asp?MemberID=2332">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2332">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2477">Tom Rooney</a>,
#  <a href="SenatorBills.asp?MemberID=2477">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2477">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2416">Chapin Rose</a>,
#  <a href="SenatorBills.asp?MemberID=2416">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2416">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2327">Martin A. Sandoval</a>,
#  <a href="SenatorBills.asp?MemberID=2327">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2327">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2484">Paul Schimpf</a>,
#  <a href="SenatorBills.asp?MemberID=2484">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2484">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2315">Ira I. Silverstein</a>,
#  <a href="SenatorBills.asp?MemberID=2315">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2315">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2417">Steve Stadelman</a>,
#  <a href="SenatorBills.asp?MemberID=2417">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2417">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2360">Heather A. Steans</a>,
#  <a href="SenatorBills.asp?MemberID=2360">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2360">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2316">Dave Syverson</a>,
#  <a href="SenatorBills.asp?MemberID=2316">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2316">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2485">Jil Tracy</a>,
#  <a href="SenatorBills.asp?MemberID=2485">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2485">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2317">Donne E. Trotter</a>,
#  <a href="SenatorBills.asp?MemberID=2317">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2317">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2418">Patricia Van Pelt</a>,
#  <a href="SenatorBills.asp?MemberID=2418">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2418">Committees</a>,
#  <a href="/senate/Senator.asp?GA=100&amp;MemberID=2469">Chuck Weaver</a>,
#  <a href="SenatorBills.asp?MemberID=2469">Bills</a>,
#  <a href="SenCommittees.asp?MemberID=2469">Committees</a>,
#  <a href="/reports/rptMemberList.asp?gaid=14&amp;ChamberId=S" target="new">click here</a>,
#  <a class="footer" href="/" title="View the General Assembly web site home page">Home</a>,
#  <a class="footer" href="/legislation/" title="View Legislation and Laws">Legislation &amp; Laws</a>,
#  <a class="footer" href="/house/default.asp" title="View information regarding House of Representatives">House</a>,
#  <a class="footer" href="/senate/default.asp" title="View information regarding Senate">Senate</a>,
#  <a class="footer" href="/mylegislation/default.asp" title="Set up customized queries, create reports for tracking, etc.">My Legislation</a>,
#  <a class="footer" href="/disclaimer.asp" title="Disclaimers regarding the Illinois General Assembly web site">Disclaimers</a>,
#  <a class="footer" href="/contact.asp" title="Contact the Illinois General Assembly Web Support Staff">Email</a>]

# %% [markdown]
# That's a lot! Many elements on a page will have the same HTML tag. For instance, if you search for everything with the `a` tag, you're likely to get a lot of stuff, much of which you don't want. What if we wanted to search for HTML tags ONLY with certain attributes, like particular CSS classes?
#
# We can do this by adding an additional argument to the `find_all`. In the example below, we are finding all the `a` tags, and then filtering those with `class = "sidemenu"`.

# %%
# get only the 'a' tags in 'sidemenu' class
soup("a", class_="sidemenu")
# Out:
# [<a class="sidemenu" href="/senate/default.asp">  Members  </a>,
#  <a class="sidemenu" href="/senate/committees/default.asp">  Committees  </a>,
#  <a class="sidemenu" href="/senate/schedules/default.asp">  Schedules  </a>,
#  <a class="sidemenu" href="/senate/journals/default.asp">  Journals  </a>,
#  <a class="sidemenu" href="/senate/transcripts/default.asp">  Transcripts  </a>,
#  <a class="sidemenu" href="/senate/rules.asp">  Rules  </a>,
#  <a class="sidemenu" href="/senateaudvid.asp">  Live Audio/Video  </a>]

# %% [markdown]
# Oftentimes a more efficient way to search and find things on a website is by **CSS selector.** For this we have to use a different method, `select()`. Just pass a string into the `.select()` to get all elements with that string as a valid CSS selector.
#
# In the example above, we can use "a.sidemenu" as a CSS selector, which returns all `a` tags with class `sidemenu`.

# %%
# get elements with "a.sidemenu" CSS Selector.
soup.select("a.sidemenu")
# Out:
# [<a class="sidemenu" href="/senate/default.asp">  Members  </a>,
#  <a class="sidemenu" href="/senate/committees/default.asp">  Committees  </a>,
#  <a class="sidemenu" href="/senate/schedules/default.asp">  Schedules  </a>,
#  <a class="sidemenu" href="/senate/journals/default.asp">  Journals  </a>,
#  <a class="sidemenu" href="/senate/transcripts/default.asp">  Transcripts  </a>,
#  <a class="sidemenu" href="/senate/rules.asp">  Rules  </a>,
#  <a class="sidemenu" href="/senateaudvid.asp">  Live Audio/Video  </a>]

# %% [markdown]
# Using CSS is one way to organize how we stylize a website. They allow us to categorize and label certain HTML elements, and use these categories and labels to apply specfic styling. CSS selectors are what we use to identify these elements, and then decide what style to apply. We won't have time today to go into detail about HTML and CSS, but it's worth talking about the three most important CSS selectors:
#
# 1. **element selector**: simply including the element type, such as `a` above, will select all elements on the page of that element type. Try using your development tools (Chrome, Firefox, or Safari) to change all elements of the type `a` to a background color of `red`.
#
# 2. **class selector**: if you put a period (`.`) before the name of a class, all elements belonging to that class will be selected. Try using your development tools to change all elements of the class `detail` to a background color of `red`.
#
# 3. **ID selector**: if you put a hashtag (`#`) before the name of an id, all elements with that id will be selected. Try using the development tools to change all elements with the id `Senate` to a background color of `red`.
#
# The above three examples will take all elements with the given property, but oftentimes you only want certain elements within the hierarchy. We can do that by simply placing elements side-by-side separated by a space.

# %% [markdown]
# ### Challenge 1
#
# Find all the `<a>` elements in class `mainmenu`

# %%
soup.select("a.mainmenu") # your code here
# Out:
# [<a class="mainmenu" href="/">Home</a>,
#  <a class="mainmenu" href="/legislation/" onblur="HM_f_PopDown('elMenu1')" onfocus="HM_f_PopUp('elMenu1',event)" onmouseout="HM_f_PopDown('elMenu1')" onmouseover="HM_f_PopUp('elMenu1',event)">Legislation &amp; Laws</a>,
#  <a class="mainmenu" href="/senate/" onblur="HM_f_PopDown('elMenu3')" onfocus="HM_f_PopUp('elMenu3',event)" onmouseout="HM_f_PopDown('elMenu3')" onmouseover="HM_f_PopUp('elMenu3',event)">Senate</a>,
#  <a class="mainmenu" href="/house/" onblur="HM_f_PopDown('elMenu2')" onfocus="HM_f_PopUp('elMenu2',event)" onmouseout="HM_f_PopDown('elMenu2')" onmouseover="HM_f_PopUp('elMenu2',event)">House</a>,
#  <a class="mainmenu" href="/mylegislation/" onblur="HM_f_PopDown('elMenu4')" onfocus="HM_f_PopUp('elMenu4',event)" onmouseout="HM_f_PopDown('elMenu4')" onmouseover="HM_f_PopUp('elMenu4',event)">My Legislation</a>,
#  <a class="mainmenu" href="/sitemap.asp">Site Map</a>]

# %% [markdown]
# ## 1.4 Get Attributes and Text of Elements
#
# Once we identify elements, we want to access information in that element. Oftentimes this means two things:
#
# 1. Text
# 2. Attributes
#
# Getting the text inside an element is easy. All we have to do is use the `text` member of a `tag` object:

# %%
# this is a list
soup.select("a.sidemenu")

# we first want to get an individual tag object
first_link = soup.select("a.sidemenu")[0]

# check out its class
print(type(first_link))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# It's a tag! Which means it has a `text` member:

# %%
print(first_link.text)
# Out:
#   Members

# %% [markdown]
# You'll see there is some extra spacing here, we can use the `strip` method to remove that:

# %%
print(first_link.text.strip())
# Out:
# Members

# %% [markdown]
# Sometimes we want the value of certain attributes. This is particularly relevant for `a` tags, or links, where the `href` attribute tells us where the link goes.
#
# You can access a tag’s attributes by treating the tag like a dictionary:

# %%
print(first_link['href'])
# Out:
# /senate/default.asp

# %% [markdown]
# Nice, but that doesn't look like a full URL! Don't worry, we'll get to this soon.

# %% [markdown]
# ### Challenge 2
#
# Find all the `href` attributes (url) from the mainmenu by writing a list comprehension and assign to it `rel_paths`.

# %%
rel_paths = [link['href'] for link in soup.select('a.mainmenu')] # your code here

# %%
print(rel_paths)
# Out:
# ['/', '/legislation/', '/senate/', '/house/', '/mylegislation/', '/sitemap.asp']

# %% [markdown]
# # 2. Collecting information
# *****
#
# Believe it or not, that's all you need to scrape a website. Let's apply these skills to scrape the [98th general assembly](http://www.ilga.gov/senate/default.asp?GA=98).
#
# Our goal is to scrape information on each senator, including their:
# * name
# * district
# * party
#
# ## 2.1 First, make the GET request and *soup* it

# %%
# make a GET request
response = requests.get('http://www.ilga.gov/senate/default.asp?GA=98')

# read the content of the server’s response
page_source = response.text

# soup it
soup = BeautifulSoup(page_source, "html5lib")

# %% [markdown]
# ## 2.2 Find the right elements and text
#
# Now let's try to get a list of rows in that table. Remember that rows are identified by the `tr` tag.

# %%
# get all tr elements
rows = soup.find_all("tr")
print(len(rows))
# Out:
# 73

# %% [markdown]
# But remember, `find_all` gets all the elements with the `tr` tag. We can use smart CSS selectors to get only the rows we want.

# %%
# returns every ‘tr tr tr’ css selector in the page
rows = soup.select('tr tr tr')
print(rows[2].prettify())
# Out:
# <tr>
#  <td bgcolor="white" class="detail" width="40%">
#   <a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">
#    Pamela J. Althoff
#   </a>
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   <a href="SenatorBills.asp?GA=98&amp;MemberID=1911">
#    Bills
#   </a>
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   <a href="SenCommittees.asp?GA=98&amp;MemberID=1911">
#    Committees
#   </a>
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   32
#  </td>
#  <td align="center" bgcolor="white" class="detail" width="15%">
#   R
#  </td>
# </tr>

# %% [markdown]
# We can use the `select` method on anything. Let's say we want to find everything with the CSS selector `td.detail` in an item of the list we created above.

# %%
# select only those 'td' tags with class 'detail'
row = rows[2]
detail_cells = row.select('td.detail')
detail_cells
# Out:
# [<td bgcolor="white" class="detail" width="40%"><a href="/senate/Senator.asp?GA=98&amp;MemberID=1911">Pamela J. Althoff</a></td>,
#  <td align="center" bgcolor="white" class="detail" width="15%"><a href="SenatorBills.asp?GA=98&amp;MemberID=1911">Bills</a></td>,
#  <td align="center" bgcolor="white" class="detail" width="15%"><a href="SenCommittees.asp?GA=98&amp;MemberID=1911">Committees</a></td>,
#  <td align="center" bgcolor="white" class="detail" width="15%">32</td>,
#  <td align="center" bgcolor="white" class="detail" width="15%">R</td>]

# %% [markdown]
# Most of the time, we're interested in the actual **text** of a website, not its tags. Remember, to get the text of an HTML element, use the `text` member.

# %%
# Keep only the text in each of those cells
row_data = [cell.text for cell in detail_cells]
print(row_data)
# Out:
# ['Pamela J. Althoff', 'Bills', 'Committees', '32', 'R']

# %% [markdown]
# Now we can combine the `BeautifulSoup` tools with our basic python skills to scrape an entire web page.

# %%
# check it out
print(row_data[0]) # name
print(row_data[3]) # district
print(row_data[4]) # party
# Out:
# Pamela J. Althoff
# 32
# R

# %% [markdown]
# ## 2.3 Loop it all together
#
# Let's use a `for` loop to get 'em all! We'll start at the beginning with the request:

# %%
# make a GET request
response = requests.get('http://www.ilga.gov/senate/default.asp?GA=98')

# read the content of the server’s response
page_source = response.text

# soup it
soup = BeautifulSoup(page_source, "html5lib")

# create empty list to store our data
members = []

# returns every ‘tr tr tr’ css selector in the page
rows = soup.select('tr tr tr')

# loop through all rows
for row in rows:

    # select only those 'td' tags with class 'detail'
    detail_cells = row.select('td.detail')
    
    # get rid of junk rows
    if len(detail_cells) is not 5: 
        continue
        
    # keep only the text in each of those cells
    row_data = [cell.text for cell in detail_cells]
    
    # collect information
    name = row_data[0]
    district = int(row_data[3])
    party = row_data[4]
    
    # store in a tuple
    tup = (name, district, party)
    
    # append to list
    members.append(tup)

# %%
print(len(members))
print()
print(members)
# Out:
# 61
#
# [('Pamela J. Althoff', 32, 'R'), ('Jason A. Barickman', 53, 'R'), ('Scott M Bennett', 52, 'D'), ('Jennifer Bertino-Tarrant', 49, 'D'), ('Daniel Biss', 9, 'D'), ('Tim Bivins', 45, 'R'), ('William E. Brady', 44, 'R'), ('Melinda Bush', 31, 'D'), ('James F. Clayborne, Jr.', 57, 'D'), ('Jacqueline Y. Collins', 16, 'D'), ('Michael Connelly', 21, 'R'), ('John J. Cullerton', 6, 'D'), ('Thomas Cullerton', 23, 'D'), ('Bill Cunningham', 18, 'D'), ('William Delgado', 2, 'D'), ('Kirk W. Dillard', 24, 'R'), ('Dan Duffy', 26, 'R'), ('Gary Forby', 59, 'D'), ('Michael W. Frerichs', 52, 'D'), ('William R. Haine', 56, 'D'), ('Don Harmon', 39, 'D'), ('Napoleon Harris, III', 15, 'D'), ('Michael E. Hastings', 19, 'D'), ('Linda Holmes', 42, 'D'), ('Mattie Hunter', 3, 'D'), ('Toi W. Hutchinson', 40, 'D'), ('Mike Jacobs', 36, 'D'), ('Emil Jones, III', 14, 'D'), ('David Koehler', 46, 'D'), ('Dan Kotowski', 28, 'D'), ('Darin M. LaHood', 37, 'R'), ('Steven M. Landek', 12, 'D'), ('Kimberly A. Lightford', 4, 'D'), ('Terry Link', 30, 'D'), ('David S. Luechtefeld', 58, 'R'), ('Andy Manar', 48, 'D'), ('Iris Y. Martinez', 20, 'D'), ('Wm. Sam McCann', 50, 'R'), ('Kyle McCarter', 54, 'R'), ('Karen McConnaughay', 33, 'R'), ('Pat McGuire', 43, 'D'), ('Julie A. Morrison', 29, 'D'), ('John G. Mulroe', 10, 'D'), ('Antonio Muñoz', 1, 'D'), ('Matt Murphy', 27, 'R'), ('Michael Noland', 22, 'D'), ('Chris Nybo', 24, 'R'), ('Jim Oberweis', 25, 'R'), ('Christine Radogno', 41, 'R'), ('Kwame Raoul', 13, 'D'), ('Sue Rezin', 38, 'R'), ('Dale A. Righter', 55, 'R'), ('Chapin Rose', 51, 'R'), ('Martin A. Sandoval', 11, 'D'), ('Ira I. Silverstein', 8, 'D'), ('Steve Stadelman', 34, 'D'), ('Heather A. Steans', 7, 'D'), ('John M. Sullivan', 47, 'D'), ('Dave Syverson', 35, 'R'), ('Donne E. Trotter', 17, 'D'), ('Patricia Van Pelt', 5, 'D')]

# %% [markdown]
# ### Challenge 3: Get HREF element pointing to members' bills
#
# The code above retrieves information on:
#
# * the senator's name
# * their district number
# * and their party
#
# We now want to retrieve the URL for each senator's list of bills. The format for the list of bills for a given senator is:
#
# http://www.ilga.gov/senate/SenatorBills.asp + ? + GA=98 + &MemberID=**_memberID_** + &Primary=True
#
# to get something like:
#
# http://www.ilga.gov/senate/SenatorBills.asp?MemberID=1911&GA=98&Primary=True
#
# You should be able to see that, unfortunately, _memberID_ is not currently something pulled out in our scraping code.
#
# Your initial task is to modify the code above so that we also **retrieve the full URL which points to the corresponding page of primary-sponsored bills**, for each member, and return it along with their name, district, and party.
#
# Tips:
#
# * To do this, you will want to get the appropriate anchor element (`<a>`) in each legislator's row of the table. You can again use the `.select()` method on the `row` object in the loop to do this — similar to the command that finds all of the `td.detail` cells in the row. Remember that we only want the link to the legislator's bills, not the committees or the legislator's profile page.
# * The anchor elements' HTML will look like `<a href="/senate/Senator.asp/...">Bills</a>`. The string in the `href` attribute contains the **relative** link we are after. You can access an attribute of a `BeatifulSoup` `Tag` object the same way you access a Python dictionary: `anchor['attributeName']`. (See the <a href="http://www.crummy.com/software/BeautifulSoup/bs4/doc/#tag">documentation</a> for more details). There are a _lot_ of different ways to use BeautifulSoup to get things done; whatever you need to do to pull that `href` out is fine.
# * Since we will only get a relative link, you'll have to do some concatenating to get the full URLs.
#
#
# **Use the code from the for-loop above and simply add the full path to the tuple, I've copied it in below**

# %%
# make a GET request
response = requests.get('http://www.ilga.gov/senate/default.asp?GA=98')

# read the content of the server’s response
page_source = response.text

# soup it
soup = BeautifulSoup(page_source, "html5lib")

# create empty list to store our data
members = []

# returns every ‘tr tr tr’ css selector in the page
rows = soup.select('tr tr tr')

# loop through all rows
for row in rows:

    # select only those 'td' tags with class 'detail'
    detail_cells = row.select('td.detail')
    
    # get rid of junk rows
    if len(detail_cells) is not 5: 
        continue
        
    # keep only the text in each of those cells
    row_data = [cell for cell in detail_cells]
    
    # collect information
    name = row_data[0].text
    district = int(row_data[3].text)
    party = row_data[4].text
    url = 'http://www.ilga.gov/senate/' + row_data[1].select('a')[0]['href'] + '&Primary=True'

    # GET FULL URLS HERE
    
    # store in a tuple
    tup = (name, district, party, url)  # ADD URL VARIABLE TO TUPLE
    
    # append to list
    members.append(tup)

# %%
members[:5]
# Out:
# [('Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True'),
#  ('Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True'),
#  ('Scott M Bennett',
#   52,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2272&Primary=True'),
#  ('Jennifer Bertino-Tarrant',
#   49,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2022&Primary=True'),
#  ('Daniel Biss',
#   9,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2020&Primary=True')]

# %% [markdown]
# Cool! Now you can probably guess how to loop it all together by iterating through the links we just extracted.

# %% [markdown]
# # 3. Following links to scrape bills
# *****
#
# ## 3.1 Writing a scraper function
#
# Now we want to scrape the webpages corresponding to bills sponsored by each senator.
#
# We're going to write a function called `get_bills(url)` to parse a given bill's URL. This will involve:
#
#   - requesting the URL using the <a href="http://docs.python-requests.org/en/latest/">`requests`</a> library
#   - using the features of the `BeautifulSoup` library to find all of the `<td>` elements with the class `billlist`
#   - return a `list` of tuples, each with:
#       - description (2nd column)
#       - chamber (S or H) (3rd column)
#       - the last action (4th column)
#       - the last action date (5th column)

# %%
def get_bills(url):
    
    # make the GET request
    response = requests.get(url)
    page_source = response.text
    soup = BeautifulSoup(page_source, "html5lib")
    
    # get the table rows
    rows = soup.select('tr tr tr')
    
    # make empty list to collect the info
    bills = []
    for row in rows:
        
        # get columns
        detail_cells = row.select('td.billlist')
        if len(detail_cells) is not 5:
            continue
            
        # get text in each column
        row_data = [cell.text for cell in row]

        # append data in columns 2-5
        bills.append(tuple(row_data[2:6]))
        
    return(bills)

# %%
# function test
test_url = members[0][3]
print(test_url)
get_bills(test_url)[0:5]
# Out:
# http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True
# [('MEDICAID BUDGET NOTE ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('HOMELESS VETERANS SHELTER ACT', 'S', 'Session Sine Die', '1/13/2015'),
#  ('ROAD FUND-NO TRANSFERS', 'S', 'Session Sine Die', '1/13/2015'),
#  ('EPA-RULES-DOCUMENT SUBMISSION',
#   'S',
#   'Public Act . . . . . . . . . 98-0072',
#   '7/15/2013'),
#  ('MIN WAGE-OVERTIME-ALTERN SHIFT', 'S', 'Session Sine Die', '1/13/2015')]

# %% [markdown]
# ## 3.2 Get all the bills
#
# Finally, we create a dictionary `bills_dict` which maps a district number (the key) onto a list_of_bills (the value) eminating from that district. You can do this by looping over all of the senate members in `members_dict` and calling `get_bills()` for each of their associated bill URLs.
#
# NOTE: Please call the function `time.sleep(5)` for each iteration of the loop, so that we don't destroy the state's web site.

# %%
bills_info = []
for member in members[:3]:  # only go through 5 members
    
    print(member[0])
    member_bills = get_bills(member[3])
    for b in member_bills:
        bill = list(member) + list(b)
        bills_info.append(bill)

    time.sleep(5)
# Out:
# Pamela J. Althoff
# Jason A. Barickman
# Scott M Bennett

# %%
bills_info
# Out:
# [['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEDICAID BUDGET NOTE ACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'HOMELESS VETERANS SHELTER ACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ROAD FUND-NO TRANSFERS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'EPA-RULES-DOCUMENT SUBMISSION',
#   'S',
#   'Public Act . . . . . . . . . 98-0072',
#   '7/15/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MIN WAGE-OVERTIME-ALTERN SHIFT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TRANSPORTATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'FOX WATERWAY FEE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'UNEMPLOYMENT INS PUBLIC SAFETY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'COUNTY BOARD MEMBERS',
#   'S',
#   'Public Act . . . . . . . . . 98-1159',
#   '1/9/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'VETERANS&MENTAL HEALTH COURTS',
#   'S',
#   'Public Act . . . . . . . . . 98-0152',
#   '8/2/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'IFA-EMERALD ASH BORER, REPORTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'LOC GOVT IMMUNITY-MUTUAL AID',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MUNI-TREATMENT OF TREES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'NURSE LICENSURE COMPACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOOD SAMARITAN ACT:RE-ENACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CORRECTIONS-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PREVAIL WAGE-LOCAL PROJECT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'FOIA/OPEN MTGS-ASSOCIATIONS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'IDPH-PRESCRIPT DRUG REPOSITORY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'BANKING-REGULATION',
#   'S',
#   'Public Act . . . . . . . . . 98-1096',
#   '8/26/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'BUSINESS-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CRIM PRO EVIDENCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0160',
#   '8/2/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ELEC CD-FILING OF PETITIONS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'OPEN MEETINGS PARKS TRAINING',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'DEDICATED FUND IMPACT NOTE ACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'DEDICATED FUND TRACKER',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'REGULATORY FUNDS-CREDIT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOMB-BUDGET TRANSPARENCY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'HOSPITL-NURS HOME-SAME BUILDNG',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'FINANCE-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MUNI CD-PUBLIC FUNDS INVEST',
#   'S',
#   'Public Act . . . . . . . . . 98-0297',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'REVENUE-TRANSFERS',
#   'S',
#   'Public Act . . . . . . . . . 98-0298',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TRANSPORTATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'STATE BUDGET-GOMB PUBLISH-WEB',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOVT TRANSPARENCY TASK FORCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0580',
#   '8/27/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'STATE GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'AUTOMATIC TELEPHONE DIALERS',
#   'S',
#   'Public Act . . . . . . . . . 98-0546',
#   '8/26/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ROAD FUND REVENUE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MOTOR FUEL TAX FUND USE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'IDPH-PRIVATE BURIAL',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TRANSPORTATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ELEC CD-ELECTION COMMISSIONERS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'SUBDIVISION ROAD TAXES',
#   'S',
#   'Public Act . . . . . . . . . 98-0818',
#   '8/1/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'SCH CD-BLOCK GRANTS-CHICAGO',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'SCH CD-ZONING COMPLIANCE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PUBLIC WORKS-HAZARDOUS TREES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PEN CD-TRANSFER-ART 5 TO ART 3',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'WATERCRAFT TOWING',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TRANSPORTATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'BOATING SAFETY REQUIREMENTS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GRANT ACCOUNTABILITY ACT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ORGAN DONOR LEAVE-BLOOD DONORS',
#   'S',
#   'Public Act . . . . . . . . . 98-0758',
#   '7/16/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PUB WATER SUPPLY OPERATIONS',
#   'S',
#   'Public Act . . . . . . . . . 98-0856',
#   '8/4/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'IHPA-AMISTAD&FREDOM TRAIL COMM',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'STATE GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CTY CD-ADMIN ORDER FINES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TRANSPORTATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'LOCAL GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'REGULATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TRANSPORTATION-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'REVENUE-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'REVENUE-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'NURS HOME-RECEIVER REIMBURSE',
#   'S',
#   'Public Act . . . . . . . . . 98-0765',
#   '7/16/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   "PROP TX-COLLECTOR'S BOOKS",
#   'S',
#   'Public Act . . . . . . . . . 98-0840',
#   '8/1/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MIN WAGE-OVERTIME-EXEMPTION',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CONSUMER FRAUD-BROADCAST SVC',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TREASURER-ADMIN CHARGE',
#   'S',
#   'Public Act . . . . . . . . . 98-0965',
#   '8/15/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PHARMACISTS-MENINGITIS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'USE/OCC-MPC EXTEND',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CONSERVATION DISTRICT-DEBT',
#   'S',
#   'Public Act . . . . . . . . . 98-1168',
#   '1/9/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CONSERV DIST-ENDANGRED SPECIES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'INC TX-R AND D CREDIT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'QUICKTAKE-MCHENRY COUNTY',
#   'S',
#   'Public Act . . . . . . . . . 98-0852',
#   '8/1/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PROP TAX-BD OF REVIEW-TAX REP',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PROP TX-ASSESSORS-BD OF REVIEW',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'NURSE LICENSURE COMPACT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT COVEY',
#   'S',
#   'Resolution Adopted',
#   '3/14/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL PATRICIA A FLOETER',
#   'S',
#   'Resolution Adopted',
#   '4/12/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DONALD MUSIELAK',
#   'S',
#   'Resolution Adopted',
#   '4/12/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RAYMOND PIERONI',
#   'S',
#   'Resolution Adopted',
#   '4/12/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   "MEMORIAL - JAMES O'DONNELL",
#   'S',
#   'Resolution Adopted',
#   '4/25/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - SANDRA HUFF',
#   'S',
#   'Resolution Adopted',
#   '4/25/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JAMES THOMPSON',
#   'S',
#   'Resolution Adopted',
#   '5/2/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARGE OLSZEWKI',
#   'S',
#   'Resolution Adopted',
#   '5/2/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL FERDINAND J STRANG SR',
#   'S',
#   'Resolution Adopted',
#   '5/2/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL JOYCE E DWYER',
#   'S',
#   'Resolution Adopted',
#   '5/17/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARY ANN HENLEY',
#   'S',
#   'Resolution Adopted',
#   '5/24/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LEROY WEGENER',
#   'S',
#   'Resolution Adopted',
#   '5/24/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DONALD PEASLEY',
#   'S',
#   'Resolution Adopted',
#   '6/19/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN SEVERS SR.',
#   'S',
#   'Resolution Adopted',
#   '6/19/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - NORMAN E. HEINRICH',
#   'S',
#   'Resolution Adopted',
#   '6/19/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN L. TOLER',
#   'S',
#   'Resolution Adopted',
#   '6/19/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JACK SLAUGHTER SR.',
#   'S',
#   'Resolution Adopted',
#   '6/19/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ARTHUR TIFFANY',
#   'S',
#   'Resolution Adopted',
#   '7/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BART WINN JR',
#   'S',
#   'Resolution Adopted',
#   '7/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GERALD DRAFFKORN SR',
#   'S',
#   'Resolution Adopted',
#   '7/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT HURLEY',
#   'S',
#   'Resolution Adopted',
#   '7/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ANTHONY V. FICK',
#   'S',
#   'Resolution Adopted',
#   '7/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - PATRICIA WAGNER',
#   'S',
#   'Resolution Adopted',
#   '7/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - FREDERICK W. NOBLE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - VALERIA WOLFF',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARY ANN RUGGERO',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOANNE T. STANEK',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DONALD J. FOLZ',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DOLORES J. POLIZZI',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DON UTHE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOSEPH KNOX',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BARBARA A. SCHMIEGE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN EDWARD KELSEY',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - KENNETH LATIMER',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARLENE J. ARVIDSON',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LILAS JEAN BEEBE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JEROME JOHNSON',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - SAMUEL OGINNI',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN WENZLAFF',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GERTRUDE SWARD',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EARL E. DUFFY',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ELEANORE REID',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT GERLOFF',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - PATRICIA ORLOFF',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JIM HARTKE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN ROURKE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - PATRICIA A. HALEY',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EDWARD A. BRYANT',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JANICE SPELLA',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - CHRISTINE FREUND',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MADELINE BOLGER',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ANNA KENNY',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - KENNETH STEINLEIN',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GREG MCCOY',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BETH ANN KLYCZEK',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - WANDA G. PALMER',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MCCD DAY',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MATTHEW PORTER',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT GAGNON',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARY ALICE BUDRECK',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ANNETTE BROGAN',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DARRELL H. EVERETT',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'SMALL BUSINESS SATURDAY',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN L. ORSO',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RALPH. E. JOHNSTON',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - KENNETH W. OLESON',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EDWARD HUGHES',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GLORIA SCHOLZ',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LOU SVADLENKA',
#   'S',
#   'Resolution Adopted',
#   '11/7/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LEE A. KURTH',
#   'S',
#   'Resolution Adopted',
#   '12/3/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BERT W. FARM',
#   'S',
#   'Resolution Adopted',
#   '12/3/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LORRAINE L. HUFFMAN',
#   'S',
#   'Resolution Adopted',
#   '12/3/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN MAY',
#   'S',
#   'Resolution Adopted',
#   '12/3/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - FAY MILLER',
#   'S',
#   'Resolution Adopted',
#   '12/3/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - HERMAN KRUEGER',
#   'S',
#   'Resolution Adopted',
#   '12/3/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT POPOVICH',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ELIZABETH RITT',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RICHARD KAZIMIER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - F. JAMES LUMBER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BETTY LESLIE',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DOLORES BELOHLAVY',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GRACE F. ANNARELLA',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL S. RASMUSSEN-HEISLER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GORDON LOHMEYER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ANTON SCHARKO',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DAVID J. TIETJEN',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - INEZ E. KNAACK',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LAWRENCE LEEKE, JR.',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BARBARA A. ROUS',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MAYNARD WHITE',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DARLENE GOEWEY',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MICHAEL A. HANSEN',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT PAULSON',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DR. SANTO RUGGERO',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RAY A. MOORE',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ARLINE G. CRAWFORD',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RANDALL JOHNSON',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARIAN ENGSTROM',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DORIS ANDREWS',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BETTY J. JACKSON',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EDWARD SCHROEDER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT RHEAD',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - WILLIAM TEGTMEIER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LYLE WALTER',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN J. SHAY',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARIE A. VOS',
#   'S',
#   'Resolution Adopted',
#   '1/29/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LOUIS HORWATH',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LUCELLE R. KRASUCKI',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LEONARD D. SOSINSKI',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT T. CENAR',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JESSIE WINKELMAN',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - PATRICIA KELLOGG',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ARLENE CARL',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MICHELLE ERICSON',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - FRANK MANSFIELD',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARION SCHWARZ',
#   'S',
#   'Resolution Adopted',
#   '2/5/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DR. JOSEPH C MORTON',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JAMES A. STUPAR',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - WALTER E. SCHULTZ',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RAYMOND G. CHISHOLM',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN KREAMCHECK',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JAMES MILLER',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RAYMOND ROBERTS',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JEROLD R. CORDREY',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MATTHEW SCHOLLE',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - PATRICIA J. NEBGEN',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DARLENE C. AEVERMAN',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EDWARD GUETTLER',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EUGENE SVOBODA',
#   'S',
#   'Resolution Adopted',
#   '2/20/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DIANE SHOGREN',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JAMES S. TONYAN',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DAVID MURREY',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL  J. ANDERSON-SCHNULLE',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - ROBERT G. NELSON',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JEAN M. SCHUETTE',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - GEORGE ROSE, JR.',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN SHERWOOD',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LOIS DEWANE',
#   'S',
#   'Resolution Adopted',
#   '3/6/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JUDITH HUTCHINSON',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RONALD J. KRESS',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JEANNINE I. BURGER',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LEONARD H. THENNES',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - BARBARA MCDONALD',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RANDALL RAABE',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EUGENE A. ROSIO',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MICHAEL W. WURTZ',
#   'S',
#   'Resolution Adopted',
#   '3/21/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EDWARD T. WINN',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LORI L. ARONSON',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOHN H. BIEDERMAN',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - EDWARD A. KRYSIAK',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - VICKI A. RODRIGUEZ',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - MARTHA LAWLESS',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - KATHLEEN M. REGNER',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JANE L. COLLINS',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOSEPH P. MARTO',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - LEON ZELVIS',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - WESLEY STERNE',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JAMES AYERS',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - WALTER PUPICH',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JOSEPH CALLAHAN',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - JAMES MCANDREWS',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - DORIS WEIDNER',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - RALPH KICK',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MEMORIAL - SUZANNE DOPKE',
#   'S',
#   'Resolution Adopted',
#   '3/27/2014'],
#  ['Pamela J. Althoff',
#   32,
# ...
#   'H',
#   'Public Act . . . . . . . . . 98-0627',
#   '3/10/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PEN CD-TRANSFER-ART 5 TO ART 3',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'WIND FARMS RENEWABLE ENERGY',
#   'H',
#   'Public Act . . . . . . . . . 98-0204',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'COUNTY-PROP LEGAL DESCRIPTION',
#   'H',
#   'Public Act . . . . . . . . . 98-0205',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PROP TX-MABAS PROP EXEMPT',
#   'H',
#   'Public Act . . . . . . . . . 98-0206',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CIVIL LAW-TECH',
#   'H',
#   'Public Act . . . . . . . . . 98-0229',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TWP-MEETING AND AGENDA',
#   'H',
#   'Bill Dead - No Positive Action Taken - Amendatory Veto',
#   '11/6/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'COUNTY ROAD FUNDS',
#   'H',
#   'Public Act . . . . . . . . . 98-0244',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'VETERINARY MEDICINE-SUNSET',
#   'H',
#   'Public Act . . . . . . . . . 98-0339',
#   '8/13/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'HOUSING COOP DISSOLUTION VOTE',
#   'H',
#   'Public Act . . . . . . . . . 98-0302',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ACCOUNTABL CARE ORG-LABORATORY',
#   'H',
#   'Public Act . . . . . . . . . 98-0708',
#   '7/16/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TOLLWAY FEE NOTIFICATION',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PRIVATE DETECTIVES-SUNSET',
#   'H',
#   'Public Act . . . . . . . . . 98-0253',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'INTERSTATE EMERGENCY AID',
#   'H',
#   'Public Act . . . . . . . . . 98-0309',
#   '8/12/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'DHS-PUB AID-LEGAL GUARDIANS',
#   'H',
#   'Public Act . . . . . . . . . 98-0256',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'OCCUPATIONAL THERAPY-SUNSET',
#   'H',
#   'Public Act . . . . . . . . . 98-0264',
#   '8/9/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'GOV. EMPLOYEE - BLOOD DONATION',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'WOMEN VETERANS TASK FORCE',
#   'H',
#   'Public Act . . . . . . . . . 98-0310',
#   '8/12/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'DRYCLEANER-FUND-REENROLLMENT',
#   'H',
#   'Public Act . . . . . . . . . 98-0327',
#   '8/13/2013'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ELEC CD-LAKE COUNTY ELECTIONS',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'FOIA-SEVERANCE AGREEMENTS',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'BOATING SAFETY: SKI FLAG',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CRIM PRO-BAIL CONDITIONS',
#   'H',
#   'Public Act . . . . . . . . . 98-1012',
#   '8/22/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'STATE GOVERNMENT-TECH',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ANIMAL WELFARE ACT-ADMIN FINES',
#   'H',
#   'Public Act . . . . . . . . . 98-0855',
#   '8/4/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'MUNI CODE-VENDING',
#   'H',
#   'Public Act . . . . . . . . . 98-1153',
#   '1/9/2015'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'CRIM CD-GROOMING-PENALTIES',
#   'H',
#   'Public Act . . . . . . . . . 98-0919',
#   '8/15/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'PENS CD-IMRF-OMITTED SERVICE',
#   'H',
#   'Public Act . . . . . . . . . 98-0932',
#   '8/15/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'ITAP-AGENCY CONTACT INFO',
#   'H',
#   'Public Act . . . . . . . . . 98-1084',
#   '8/26/2014'],
#  ['Pamela J. Althoff',
#   32,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=1911&Primary=True',
#   'TURKISH RELATIONS TASK FORCE',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MUNI-VETERAN QUALIFICATION',
#   'S',
#   'Public Act . . . . . . . . . 98-0510',
#   '8/19/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CRIMINAL LAW-TECH',
#   'S',
#   'Public Act . . . . . . . . . 98-0579',
#   '8/27/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CIVIL LAW-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'REGULATION-TECH',
#   'S',
#   'Public Act . . . . . . . . . 98-0540',
#   '8/23/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CIV PRO-ADMISSABILITY-PHOTOS',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'REENACT 94-677 INSUR INTEREST',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CRIM CD-VEHICLE FORFEITURE',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'WIRELESS CARRIER-NO FUND SWEEP',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'TIF- GIBSON CITY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'INS CD-CERTIFICATE-INSURANCE',
#   'S',
#   'Public Act . . . . . . . . . 98-0819',
#   '8/1/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'RESID PROP-TRANSFER ON DEATH',
#   'S',
#   'Public Act . . . . . . . . . 98-0821',
#   '8/1/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'FIREARM OWNERS ID-RENEWAL-FEES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'ESTATE TAX-EXCLUSION AMOUNT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'OPEN MEETINGS PARKS TRAINING',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'SEX OFFENDER REG-EMPLOYMENT',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'BANK SERV TRUST FUND-USES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'DEBT LIMIT-MILFORD TWP H.S.',
#   'S',
#   'Public Act . . . . . . . . . 98-1112',
#   '8/26/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'PREVAILING WAGE-CLASSIFICATION',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'STATE GOVERNMENT-TECH',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'EMS-TRANSPORT-OTHER FACILITIES',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'HIGHER ED-PREPD TUITION-CERTFY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'PREPAID TUITION CONTRACTS-END',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL JUDITH BOYER',
#   'S',
#   'Resolution Adopted',
#   '2/7/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - CHRISTOPHER BROWN',
#   'S',
#   'Resolution Adopted',
#   '3/14/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - ROBERT LETE',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - JEFFREY HILTON',
#   'S',
#   'Resolution Adopted',
#   '10/23/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'ENDANGERED SPECIES DAY',
#   'S',
#   'Resolution Adopted',
#   '3/20/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - HAROLD INGOLD',
#   'S',
#   'Resolution Adopted',
#   '5/1/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - STAN HOSELTON',
#   'S',
#   'Resolution Adopted',
#   '5/8/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL-BERNADINE FITZGERALD',
#   'S',
#   'Resolution Adopted',
#   '5/31/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - DAVID BAILEY',
#   'S',
#   'Resolution Adopted',
#   '11/20/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - E. LESLIE CONKLING',
#   'S',
#   'Resolution Adopted',
#   '11/20/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - GEORGE KNUDSEN',
#   'S',
#   'Resolution Adopted',
#   '11/20/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'SGT. GARY SCOTT MEM HIGHWAY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'MEMORIAL - RABBI ISAAC NEUMAN',
#   'S',
#   'Resolution Adopted',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CASEY J. KOHLMEIER MEM HIGHWAY',
#   'S',
#   'Adopted Both Houses',
#   '4/2/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'SGT. GARY SCOTT MEM HIGHWAY',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CON AMEND-BIENNIAL BUDGET',
#   'S',
#   'Session Sine Die',
#   '1/13/2015'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'OPEN MEETINGS PARKS TRAINING',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'IFA-AGRIBUSINESS EXPERT MEMBER',
#   'H',
#   'Public Act . . . . . . . . . 98-0344',
#   '8/13/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'EAVESDROPPING-CIVIL REMEDIES',
#   'H',
#   'Public Act . . . . . . . . . 98-0268',
#   '8/9/2013'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'ARCHERY EQUIPMENT TRANSPORT',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'BANK SERV TRUST FUND-USES',
#   'H',
#   'Public Act . . . . . . . . . 98-0909',
#   '8/15/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'DEBT LIMIT-MILFORD TWP H.S.',
#   'H',
#   'Public Act . . . . . . . . . 98-0916',
#   '8/15/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'RIGHT OF WAY/EMERGENCY VEH',
#   'H',
#   'Session Sine Die',
#   '12/3/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'VEH CD-NIGHTTIME PERMIT',
#   'H',
#   'Public Act . . . . . . . . . 98-0746',
#   '7/16/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'VISION AID LICENSE RENEWAL',
#   'H',
#   'Public Act . . . . . . . . . 98-0747',
#   '7/16/2014'],
#  ['Jason A. Barickman',
#   53,
#   'R',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2018&Primary=True',
#   'CHRIS R BROWN MEMORIAL HIGHWAY',
#   'H',
#   'Adopted Both Houses',
#   '11/7/2013'],
#  ['Scott M Bennett',
#   52,
#   'D',
#   'http://www.ilga.gov/senate/SenatorBills.asp?GA=98&MemberID=2272&Primary=True',
#   'MEMORIAL - THOMAS G. HAYS',
#   'S',
#   'Resolution Adopted',
#   '1/13/2015']]

# %% [markdown]
# # 4. Export to CSV

# %% [markdown]
# We can write this to a CSV too:

# %%
# manually decide on header names
header = ['Senator', 'District', 'Party', 'Bills Link', 'Description', 'Chamber', 'Last Action', 'Last Action Date']

with open('all-bills.csv', 'w') as output_file:
    csv_writer = csv.writer(output_file)
    csv_writer.writerow(header)
    csv_writer.writerows(bills_info)
    
pandas.read_csv('all-bills.csv')
# Out:
#                 Senator  District Party  \
# 0     Pamela J. Althoff        32     R
# 1     Pamela J. Althoff        32     R
# 2     Pamela J. Althoff        32     R
# 3     Pamela J. Althoff        32     R
# 4     Pamela J. Althoff        32     R
# 5     Pamela J. Althoff        32     R
# 6     Pamela J. Althoff        32     R
# 7     Pamela J. Althoff        32     R
# 8     Pamela J. Althoff        32     R
# 9     Pamela J. Althoff        32     R
# 10    Pamela J. Althoff        32     R
# 11    Pamela J. Althoff        32     R
# 12    Pamela J. Althoff        32     R
# 13    Pamela J. Althoff        32     R
# 14    Pamela J. Althoff        32     R
# 15    Pamela J. Althoff        32     R
# 16    Pamela J. Althoff        32     R
# 17    Pamela J. Althoff        32     R
# 18    Pamela J. Althoff        32     R
# 19    Pamela J. Althoff        32     R
# 20    Pamela J. Althoff        32     R
# 21    Pamela J. Althoff        32     R
# 22    Pamela J. Althoff        32     R
# 23    Pamela J. Althoff        32     R
# 24    Pamela J. Althoff        32     R
# 25    Pamela J. Althoff        32     R
# 26    Pamela J. Althoff        32     R
# 27    Pamela J. Althoff        32     R
# 28    Pamela J. Althoff        32     R
# 29    Pamela J. Althoff        32     R
# ..                  ...       ...   ...
# 459  Jason A. Barickman        53     R
# 460  Jason A. Barickman        53     R
# 461  Jason A. Barickman        53     R
# 462  Jason A. Barickman        53     R
# 463  Jason A. Barickman        53     R
# 464  Jason A. Barickman        53     R
# 465  Jason A. Barickman        53     R
# 466  Jason A. Barickman        53     R
# 467  Jason A. Barickman        53     R
# 468  Jason A. Barickman        53     R
# 469  Jason A. Barickman        53     R
# 470  Jason A. Barickman        53     R
# 471  Jason A. Barickman        53     R
# 472  Jason A. Barickman        53     R
# 473  Jason A. Barickman        53     R
# 474  Jason A. Barickman        53     R
# 475  Jason A. Barickman        53     R
# 476  Jason A. Barickman        53     R
# 477  Jason A. Barickman        53     R
# 478  Jason A. Barickman        53     R
# 479  Jason A. Barickman        53     R
# 480  Jason A. Barickman        53     R
# 481  Jason A. Barickman        53     R
# 482  Jason A. Barickman        53     R
# 483  Jason A. Barickman        53     R
# 484  Jason A. Barickman        53     R
# 485  Jason A. Barickman        53     R
# 486  Jason A. Barickman        53     R
# 487  Jason A. Barickman        53     R
# 488     Scott M Bennett        52     D
#
#                                             Bills Link  \
# 0    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 1    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 2    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 3    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 4    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 5    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 6    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 7    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 8    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 9    http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 10   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 11   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 12   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 13   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 14   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 15   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 16   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 17   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 18   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 19   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 20   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 21   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 22   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 23   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 24   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 25   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 26   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 27   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 28   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 29   http://www.ilga.gov/senate/SenatorBills.asp?GA...
# ..                                                 ...
# 459  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 460  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 461  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 462  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 463  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 464  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 465  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 466  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 467  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 468  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 469  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 470  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 471  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 472  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 473  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 474  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 475  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 476  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 477  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 478  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 479  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 480  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 481  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 482  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 483  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 484  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 485  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 486  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 487  http://www.ilga.gov/senate/SenatorBills.asp?GA...
# 488  http://www.ilga.gov/senate/SenatorBills.asp?GA...
#
#                         Description Chamber  \
# 0          MEDICAID BUDGET NOTE ACT       S
# 1     HOMELESS VETERANS SHELTER ACT       S
# 2            ROAD FUND-NO TRANSFERS       S
# 3     EPA-RULES-DOCUMENT SUBMISSION       S
# 4    MIN WAGE-OVERTIME-ALTERN SHIFT       S
# 5               TRANSPORTATION-TECH       S
# 6                  FOX WATERWAY FEE       S
# 7    UNEMPLOYMENT INS PUBLIC SAFETY       S
# 8              COUNTY BOARD MEMBERS       S
# 9     VETERANS&MENTAL HEALTH COURTS       S
# 10   IFA-EMERALD ASH BORER, REPORTS       S
# 11     LOC GOVT IMMUNITY-MUTUAL AID       S
# 12          MUNI-TREATMENT OF TREES       S
# 13          NURSE LICENSURE COMPACT       S
# 14      GOOD SAMARITAN ACT:RE-ENACT       S
# 15                 CORRECTIONS-TECH       S
# 16       PREVAIL WAGE-LOCAL PROJECT       S
# 17      FOIA/OPEN MTGS-ASSOCIATIONS       S
# 18   IDPH-PRESCRIPT DRUG REPOSITORY       S
# 19               BANKING-REGULATION       S
# 20                    BUSINESS-TECH       S
# 21                CRIM PRO EVIDENCE       S
# 22      ELEC CD-FILING OF PETITIONS       S
# 23     OPEN MEETINGS PARKS TRAINING       S
# 24   DEDICATED FUND IMPACT NOTE ACT       S
# 25           DEDICATED FUND TRACKER       S
# 26          REGULATORY FUNDS-CREDIT       S
# 27         GOMB-BUDGET TRANSPARENCY       S
# 28   HOSPITL-NURS HOME-SAME BUILDNG       S
# 29                     FINANCE-TECH       S
# ..                              ...     ...
# 459  EMS-TRANSPORT-OTHER FACILITIES       S
# 460  HIGHER ED-PREPD TUITION-CERTFY       S
# 461   PREPAID TUITION CONTRACTS-END       S
# 462           MEMORIAL JUDITH BOYER       S
# 463    MEMORIAL - CHRISTOPHER BROWN       S
# 464          MEMORIAL - ROBERT LETE       S
# 465       MEMORIAL - JEFFREY HILTON       S
# 466          ENDANGERED SPECIES DAY       S
# 467        MEMORIAL - HAROLD INGOLD       S
# 468        MEMORIAL - STAN HOSELTON       S
# 469   MEMORIAL-BERNADINE FITZGERALD       S
# 470         MEMORIAL - DAVID BAILEY       S
# 471   MEMORIAL - E. LESLIE CONKLING       S
# 472       MEMORIAL - GEORGE KNUDSEN       S
# 473     SGT. GARY SCOTT MEM HIGHWAY       S
# 474   MEMORIAL - RABBI ISAAC NEUMAN       S
# 475  CASEY J. KOHLMEIER MEM HIGHWAY       S
# 476     SGT. GARY SCOTT MEM HIGHWAY       S
# 477       CON AMEND-BIENNIAL BUDGET       S
# 478    OPEN MEETINGS PARKS TRAINING       H
# 479  IFA-AGRIBUSINESS EXPERT MEMBER       H
# 480    EAVESDROPPING-CIVIL REMEDIES       H
# 481     ARCHERY EQUIPMENT TRANSPORT       H
# 482       BANK SERV TRUST FUND-USES       H
# 483     DEBT LIMIT-MILFORD TWP H.S.       H
# 484      RIGHT OF WAY/EMERGENCY VEH       H
# 485         VEH CD-NIGHTTIME PERMIT       H
# 486      VISION AID LICENSE RENEWAL       H
# 487  CHRIS R BROWN MEMORIAL HIGHWAY       H
# 488       MEMORIAL - THOMAS G. HAYS       S
#
#                               Last Action Last Action Date
# 0                        Session Sine Die        1/13/2015
# 1                        Session Sine Die        1/13/2015
# 2                        Session Sine Die        1/13/2015
# 3    Public Act . . . . . . . . . 98-0072        7/15/2013
# 4                        Session Sine Die        1/13/2015
# 5                        Session Sine Die        1/13/2015
# 6                        Session Sine Die        1/13/2015
# 7                        Session Sine Die        1/13/2015
# 8    Public Act . . . . . . . . . 98-1159         1/9/2015
# 9    Public Act . . . . . . . . . 98-0152         8/2/2013
# 10                       Session Sine Die        1/13/2015
# 11                       Session Sine Die        1/13/2015
# 12                       Session Sine Die        1/13/2015
# 13                       Session Sine Die        1/13/2015
# 14                       Session Sine Die        1/13/2015
# 15                       Session Sine Die        1/13/2015
# 16                       Session Sine Die        1/13/2015
# 17                       Session Sine Die        1/13/2015
# 18                       Session Sine Die        1/13/2015
# 19   Public Act . . . . . . . . . 98-1096        8/26/2014
# 20                       Session Sine Die        1/13/2015
# 21   Public Act . . . . . . . . . 98-0160         8/2/2013
# 22                       Session Sine Die        1/13/2015
# 23                       Session Sine Die        1/13/2015
# 24                       Session Sine Die        1/13/2015
# 25                       Session Sine Die        1/13/2015
# 26                       Session Sine Die        1/13/2015
# 27                       Session Sine Die        1/13/2015
# 28                       Session Sine Die        1/13/2015
# 29                       Session Sine Die        1/13/2015
# ..                                    ...              ...
# 459                      Session Sine Die        1/13/2015
# 460                      Session Sine Die        1/13/2015
# 461                      Session Sine Die        1/13/2015
# 462                    Resolution Adopted         2/7/2013
# 463                    Resolution Adopted        3/14/2013
# 464                    Resolution Adopted       10/23/2013
# 465                    Resolution Adopted       10/23/2013
# 466                    Resolution Adopted        3/20/2014
# 467                    Resolution Adopted         5/1/2014
# 468                    Resolution Adopted         5/8/2014
# 469                    Resolution Adopted        5/31/2014
# 470                    Resolution Adopted       11/20/2014
# 471                    Resolution Adopted       11/20/2014
# 472                    Resolution Adopted       11/20/2014
# 473                      Session Sine Die        1/13/2015
# 474                    Resolution Adopted        1/13/2015
# 475                   Adopted Both Houses         4/2/2014
# 476                      Session Sine Die        1/13/2015
# 477                      Session Sine Die        1/13/2015
# 478                      Session Sine Die        12/3/2014
# 479  Public Act . . . . . . . . . 98-0344        8/13/2013
# 480  Public Act . . . . . . . . . 98-0268         8/9/2013
# 481                      Session Sine Die        12/3/2014
# 482  Public Act . . . . . . . . . 98-0909        8/15/2014
# 483  Public Act . . . . . . . . . 98-0916        8/15/2014
# 484                      Session Sine Die        12/3/2014
# 485  Public Act . . . . . . . . . 98-0746        7/16/2014
# 486  Public Act . . . . . . . . . 98-0747        7/16/2014
# 487                   Adopted Both Houses        11/7/2013
# 488                    Resolution Adopted        1/13/2015
#
# [489 rows x 8 columns]
